# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_file = "../data/raw/SFHS_byState.csv"

# %%
homeSales_df = pd.read_csv(data_file)
homeSales_df.head()
# Out:
#         State  1/31/1996  2/29/1996  3/31/1996  4/30/1996  5/31/1996  \
# 0      Alaska     128799     129299     129737     130648     131314
# 1     Alabama      82282      82384      82466      82582      82646
# 2    Arkansas      68557      68588      68665      68774      68901
# 3     Arizona     110353     110668     111028     111685     112300
# 4  California     164133     163906     163766     163493     163318
#
#    6/30/1996  7/31/1996  8/31/1996  9/30/1996  ...  6/30/2019  7/31/2019  \
# 0     131931     132415     132795     133037  ...     323118     323206
# 1      82747      82888      83096      83221  ...     136491     137034
# 2      69015      69166      69333      69494  ...     127013     127431
# 3     112856     113368     113838     114287  ...     267246     268612
# 4     163183     163107     163113     163162  ...     562386     563398
#
#    8/31/2019  9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  \
# ...

# %%
homeSales_df.shape
# Out:
# (47, 292)

# %%
homeSales_df.set_index("State", inplace=True)
homeSales_df.head()
# Out:
#             1/31/1996  2/29/1996  3/31/1996  4/30/1996  5/31/1996  6/30/1996  \
# State
# Alaska         128799     129299     129737     130648     131314     131931
# Alabama         82282      82384      82466      82582      82646      82747
# Arkansas        68557      68588      68665      68774      68901      69015
# Arizona        110353     110668     111028     111685     112300     112856
# California     164133     163906     163766     163493     163318     163183
#
#             7/31/1996  8/31/1996  9/30/1996  10/31/1996  ...  6/30/2019  \
# State                                                    ...
# Alaska         132415     132795     133037      133078  ...     323118
# Alabama         82888      83096      83221       83344  ...     136491
# Arkansas        69166      69333      69494       69673  ...     127013
# Arizona        113368     113838     114287      114739  ...     267246
# California     163107     163113     163162      163339  ...     562386
#
# ...

# %%
homeSales_df.dtypes
# Out:
# 1/31/1996     int64
# 2/29/1996     int64
# 3/31/1996     int64
# 4/30/1996     int64
# 5/31/1996     int64
#               ...
# 11/30/2019    int64
# 12/31/2019    int64
# 1/31/2020     int64
# 2/29/2020     int64
# 3/31/2020     int64
# Length: 291, dtype: object

# %%
homeSales_df = homeSales_df.T
homeSales_df
# Out:
# State       Alaska  Alabama  Arkansas  Arizona  California  Colorado  \
# 1/31/1996   128799    82282     68557   110353      164133    143302
# 2/29/1996   129299    82384     68588   110668      163906    143773
# 3/31/1996   129737    82466     68665   111028      163766    144161
# 4/30/1996   130648    82582     68774   111685      163493    144946
# 5/31/1996   131314    82646     68901   112300      163318    145634
# ...            ...      ...       ...      ...         ...       ...
# 11/30/2019  321087   139404    129169   275153      571142    412016
# 12/31/2019  319754   140138    129477   277367      574142    413219
# 1/31/2020   319753   140881    129787   279482      577601    414960
# 2/29/2020   317470   141646    130180   281581      581867    416567
# 3/31/2020   314518   142463    130638   283974      586271    418359
#
# State       Connecticut  District of Columbia  Delaware  Florida  ...  \
# ...

# %%
homeSales_df.to_csv("../data/CLEANED_SFHS_byState.csv")
