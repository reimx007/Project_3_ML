# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../../data/CLEANED_National_SFHS_CR_edits.csv")
df.head()
# Out:
#    Unnamed: 0 Unnamed: 0.1  Alaska  Alabama  Arkansas  Arizona  California  \
# 0           0    1/31/1996  128799    82282     68557   110353      164133
# 1           1    2/29/1996  129299    82384     68588   110668      163906
# 2           2    3/31/1996  129737    82466     68665   111028      163766
# 3           3    4/30/1996  130648    82582     68774   111685      163493
# 4           4    5/31/1996  131314    82646     68901   112300      163318
#
#    Colorado  Connecticut  District of Columbia  ...  Texas    Utah  Virginia  \
# 0    143302       157679                195151  ...  98043  160686    122364
# 1    143773       157478                194150  ...  98068  160818    122311
# 2    144161       157722                193289  ...  98099  161092    122319
# 3    144946       157889                191849  ...  98226  161570    122300
# 4    145634       158013                190734  ...  98368  162209    122256
#
# ...

# %%
states = []
for col in df.columns:
    states.append(col)
states.remove('month') 
states.remove('year')
states.remove('date')
states.remove('Unnamed: 0')  
print(states)
# Out:
# ['Unnamed: 0.1', 'Alaska', 'Alabama', 'Arkansas', 'Arizona', 'California', 'Colorado', 'Connecticut', 'District of Columbia', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Iowa', 'Idaho', 'Illinois', 'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Massachusetts', 'Maryland', 'Maine', 'Michigan', 'Minnesota', 'Missouri', 'Mississippi', 'North Carolina', 'Nebraska', 'New Hampshire', 'New Jersey', 'Nevada', 'New York', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Virginia', 'Vermont', 'Washington', 'Wisconsin', 'West Virginia']

# %%
new_df = df.rename(columns={'Unnamed: 0.1': 'date'})
new_df
# Out:
#      Unnamed: 0        date  Alaska  Alabama  Arkansas  Arizona  California  \
# 0             0   1/31/1996  128799    82282     68557   110353      164133
# 1             1   2/29/1996  129299    82384     68588   110668      163906
# 2             2   3/31/1996  129737    82466     68665   111028      163766
# 3             3   4/30/1996  130648    82582     68774   111685      163493
# 4             4   5/31/1996  131314    82646     68901   112300      163318
# ..          ...         ...     ...      ...       ...      ...         ...
# 286         286  11/30/2019  321087   139404    129169   275153      571142
# 287         287  12/31/2019  319754   140138    129477   277367      574142
# 288         288   1/31/2020  319753   140881    129787   279482      577601
# 289         289   2/29/2020  317470   141646    130180   281581      581867
# 290         290   3/31/2020  314518   142463    130638   283974      586271
#
# ...

# %%
new_df.drop(columns=['Unnamed: 0'])
new_df
# Out:
#      Unnamed: 0        date  Alaska  Alabama  Arkansas  Arizona  California  \
# 0             0   1/31/1996  128799    82282     68557   110353      164133
# 1             1   2/29/1996  129299    82384     68588   110668      163906
# 2             2   3/31/1996  129737    82466     68665   111028      163766
# 3             3   4/30/1996  130648    82582     68774   111685      163493
# 4             4   5/31/1996  131314    82646     68901   112300      163318
# ..          ...         ...     ...      ...       ...      ...         ...
# 286         286  11/30/2019  321087   139404    129169   275153      571142
# 287         287  12/31/2019  319754   140138    129477   277367      574142
# 288         288   1/31/2020  319753   140881    129787   279482      577601
# 289         289   2/29/2020  317470   141646    130180   281581      581867
# 290         290   3/31/2020  314518   142463    130638   283974      586271
#
# ...

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this
# Minnesota only

X = new_df.date.values.reshape(-1, 1)
y = new_df.Minnesota.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
X
# Out:
# Shape:  (582, 1) (291, 1)
# array([['1/31/1996'],
#        [199601],
#        ['2/29/1996'],
#        [199602],
#        ['3/31/1996'],
#        [199603],
#        ['4/30/1996'],
#        [199604],
#        ['5/31/1996'],
#        [199605],
#        ['6/30/1996'],
#        [199606],
#        ['7/31/1996'],
#        [199607],
#        ['8/31/1996'],
#        [199608],
#        ['9/30/1996'],
#        [199609],
#        ['10/31/1996'],
#        [199610],
#        ['11/30/1996'],
#        [199611],
#        ['12/31/1996'],
#        [199612],
#        ['1/31/1997'],
#        [199701],
#        ['2/28/1997'],
#        [199702],
#        ['3/31/1997'],
#        [199703],
#        ['4/30/1997'],
#        [199704],
#        ['5/31/1997'],
#        [199705],
#        ['6/30/1997'],
#        [199706],
#        ['7/31/1997'],
#        [199707],
#        ['8/31/1997'],
#        [199708],
#        ['9/30/1997'],
#        [199709],
#        ['10/31/1997'],
#        [199710],
# ...

# %%
# Plot the data

### BEGIN SOLUTION

plt.scatter(X, y)

### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5d00885643cb> in <module>
#       3 ### BEGIN SOLUTION
#       4
# ----> 5 plt.scatter(X, y)
#       6
#       7 ### END SOLUTION
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# ...
