# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rent_data = "../data/Apartment-List-Rent-Data-State_2020-4.csv"

# %%
#DataFrame showing breakdown for each month of each yr. btwn 2014-2019 for each state
rent_df = pd.read_csv(rent_data)
rent_df
# Out:
#     Location Bedroom_Size  Price_2014_01  Price_2014_02  Price_2014_03  \
# 0    Alabama       Studio            573            573            574
# 1    Alabama          1br            624            624            625
# 2    Alabama          2br            758            758            759
# 3    Alabama          3br           1013           1013           1014
# 4    Alabama          4br           1178           1178           1179
# ..       ...          ...            ...            ...            ...
# 245  Wyoming       Studio            557            554            553
# 246  Wyoming          1br            624            621            620
# 247  Wyoming          2br            801            797            796
# 248  Wyoming          3br           1089           1084           1083
# 249  Wyoming          4br           1288           1283           1281
#
#      Price_2014_04  Price_2014_05  Price_2014_06  Price_2014_07  \
# ...

# %%
#DataFrame showing only annual average rents for each state
reduced_rent_df = rent_df[["Location", "Bedroom_Size", "avg_2014", "avg_2015", "avg_2016", "avg_2017", "avg_2018", "avg_2019", "avg_2020"]]
reduced_rent_df.head(40)
# Out:
#        Location Bedroom_Size  avg_2014  avg_2015  avg_2016  avg_2017  \
# 0       Alabama       Studio    576.92    580.08    584.08    598.08
# 1       Alabama          1br    628.00    631.50    635.83    650.83
# 2       Alabama          2br    762.83    767.17    772.33    790.92
# 3       Alabama          3br   1019.50   1025.25   1032.17   1056.83
# 4       Alabama          4br   1185.67   1192.50   1200.42   1229.33
# 5        Alaska       Studio    852.00    852.08    833.17    820.08
# 6        Alaska          1br    973.50    973.75    952.08    937.17
# 7        Alaska          2br   1245.17   1245.25   1217.75   1198.58
# 8        Alaska          3br   1759.67   1760.17   1721.17   1693.92
# 9        Alaska          4br   2112.75   2113.17   2066.33   2033.50
# 10      Arizona       Studio    610.00    633.25    655.00    681.83
# 11      Arizona          1br    720.42    748.08    773.58    805.58
# 12      Arizona          2br    910.33    944.92    976.92   1017.58
# ...

# %%
Alabama_df = pd.DataFrame(rent_df.loc[rent_df["Location"]== "Alabama", :])
Alabama_df
# Out:
#   Location Bedroom_Size  Price_2014_01  Price_2014_02  Price_2014_03  \
# 0  Alabama       Studio            573            573            574
# 1  Alabama          1br            624            624            625
# 2  Alabama          2br            758            758            759
# 3  Alabama          3br           1013           1013           1014
# 4  Alabama          4br           1178           1178           1179
#
#    Price_2014_04  Price_2014_05  Price_2014_06  Price_2014_07  Price_2014_08  \
# 0            574            575            576          578.0          580.0
# 1            625            626            627          629.0          631.0
# 2            759            760            762          765.0          766.0
# 3           1015           1016           1018         1022.0         1024.0
# 4           1180           1182           1184         1188.0         1191.0
#
#    ...  Price_2019_09  Price_2019_10  Price_2019_11  Price_2019_12  avg_2019  \
# ...

# %%
Minnesota_df = pd.DataFrame(rent_df.loc[rent_df["Location"] == "Minnesota", :])
Minnesota_df
# Out:
#       Location Bedroom_Size  Price_2014_01  Price_2014_02  Price_2014_03  \
# 110  Minnesota       Studio            608            609            610
# 111  Minnesota          1br            738            739            741
# 112  Minnesota          2br            938            940            942
# 113  Minnesota          3br           1302           1305           1308
# 114  Minnesota          4br           1524           1527           1530
#
#      Price_2014_04  Price_2014_05  Price_2014_06  Price_2014_07  \
# 110            612            614            616          619.0
# 111            743            746            748          751.0
# 112            945            948            951          955.0
# 113           1312           1316           1321         1326.0
# 114           1535           1540           1546         1552.0
#
#      Price_2014_08  ...  Price_2019_09  Price_2019_10  Price_2019_11  \
# ...

# %% [markdown]
# Rule of thumb: expect to pay approx. 30% of gross monthly income for rent.

# %%
reduced_rent_df.to_csv("../data/rent_avg_by_yr.csv")
